# %%
import pandas as pd #import pandas for dataframe operations
import numpy as np #import numpy for numerical operation
import matplotlib.pyplot as plt #import pyplot module of matplotlib
import seaborn as sns #import seaborn
#to make all plots to be displayed just below the code.
# %matplotlib inline

# %%
df= pd.read_csv("did1.csv")

# %%
df.head() #returns the first 5 default entries of the dataset
# Out:
#      did_id src_nm    src_id drug_raw_name cas_cas_no    cas_pt cas_source  \
# 0  1_000001  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 1  1_000002  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 2  1_000003  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 3  1_000004  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 4  1_000005  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
#
#           cas_match chebi_pt  chebi_id  ... ind_umls_sem_typ4  \
# 0  <syn per source>      NaN       NaN  ...               NaN
# 1  <syn per source>      NaN       NaN  ...               NaN
# 2  <syn per source>      NaN       NaN  ...               NaN
# 3  <syn per source>      NaN       NaN  ...               NaN
# 4  <syn per source>      NaN       NaN  ...               NaN
#
#   ind_umls_in_term_match ind_umls_in_term ind_umls_in_pt  ind_umls_in_cui  \
# 0                    NaN              NaN            NaN              NaN
# 1                    NaN              NaN            NaN              NaN
# 2                    NaN              NaN            NaN              NaN
# 3                    NaN              NaN            NaN              NaN
# 4                    NaN              NaN            NaN              NaN
#
#   ind_umls_in_term_typ ind_umls_in_sem_typ1 ind_umls_in_sem_typ2  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#   ind_umls_in_sem_typ3 ind_umls_in_sem_typ4
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
#
# [5 rows x 64 columns]

# %%
df.tail() #returns the last 5 default entries of the dataset
# Out:
#       did_id   src_nm   src_id                     drug_raw_name  cas_cas_no  \
# 94  1_000095  MeSH_PA  C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 95  1_000096  MeSH_PA  C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 96  1_000097  MeSH_PA  C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 97  1_000098  MeSH_PA  C057837  3,7-dimethyl-1-propargylxanthine  14114-46-6
# 98  1_000099  MeSH_PA  C057837  3,7-dimethyl-1-propargylxanthine  14114-46-6
#
#                               cas_pt cas_source cas_match       chebi_pt  \
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+     exact  dilC18(3)(1+)
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+     exact  dilC18(3)(1+)
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+     exact  dilC18(3)(1+)
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+     exact            NaN
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+     exact            NaN
#
#     chebi_id  ... ind_umls_sem_typ4 ind_umls_in_term_match  \
# 94   52818.0  ...               NaN                    NaN
# 95   52818.0  ...               NaN                    NaN
# 96   52818.0  ...               NaN                    NaN
# 97       NaN  ...               NaN      exact (CUI-based)
# 98       NaN  ...               NaN      exact (CUI-based)
#
#                      ind_umls_in_term                     ind_umls_in_pt  \
# 94                                NaN                                NaN
# 95                                NaN                                NaN
# 96                                NaN                                NaN
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_umls_in_cui ind_umls_in_term_typ                ind_umls_in_sem_typ1  \
# 94              NaN                  NaN                                 NaN
# 95              NaN                  NaN                                 NaN
# 96              NaN                  NaN                                 NaN
# 97        2936570.0                    P  A1.4.1.1.1_Pharmacologic Substance
# 98         243051.0                    P  A1.4.1.1.1_Pharmacologic Substance
#
#    ind_umls_in_sem_typ2 ind_umls_in_sem_typ3 ind_umls_in_sem_typ4
# 94                  NaN                  NaN                  NaN
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
# [5 rows x 64 columns]

# %%
df.columns
# Out:
# Index(['did_id', 'src_nm', 'src_id', 'drug_raw_name', 'cas_cas_no', 'cas_pt',
#        'cas_source', 'cas_match', 'chebi_pt', 'chebi_id', 'chebi_cas_no',
#        'chebi_match', 'chebi_syn', 'chebi_syn_match', 'chebi_match_aid',
#        'chemid_pt', 'chemid_display_name', 'chemid_id', 'chemi_match',
#        'chemid_syn', 'chemid_syn_match', 'chemid_match_aid', 'ctd_pt',
#        'ctd_mesh_id', 'ctd_cas_no', 'ctd_match', 'ctd_syn', 'ctd_syn_match',
#        'ctd_match_aid', 'umls_pt', 'umls_cui', 'umls_match', 'umls_syn',
#        'umls_syn_match', 'umls_match_aid', 'umls_sem_typ1', 'umls_sem_typ2',
#        'umls_sem_typ3', 'umls_sem_typ4', 'ind_raw', 'ind_agg', 'ind_search',
#        'ind_raw_value', 'ind_raw_target', 'ind_raw_match',
#        'ind_umls_entry_term_match', 'ind_umls_entry_term', 'ind_umls_pt',
#        'und_umls_cuii', 'ind_umls_term_typ', 'ind_umls_pheno_flg',
#        'ind_umls_sem_typ1', 'ind_umls_sem_typ2', 'ind_umls_sem_typ3',
#        'ind_umls_sem_typ4', 'ind_umls_in_term_match', 'ind_umls_in_term',
#        'ind_umls_in_pt', 'ind_umls_in_cui', 'ind_umls_in_term_typ',
#        'ind_umls_in_sem_typ1', 'ind_umls_in_sem_typ2', 'ind_umls_in_sem_typ3',
#        'ind_umls_in_sem_typ4'],
#       dtype='object')

# %%
df.shape #how big is data
# Out:
# (99, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 64 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     99 non-null     object
#  1   src_nm                     99 non-null     object
#  2   src_id                     95 non-null     object
#  3   drug_raw_name              99 non-null     object
#  4   cas_cas_no                 85 non-null     object
#  5   cas_pt                     85 non-null     object
#  6   cas_source                 85 non-null     object
#  7   cas_match                  85 non-null     object
#  8   chebi_pt                   34 non-null     object
#  9   chebi_id                   34 non-null     float64
#  10  chebi_cas_no               29 non-null     object
#  11  chebi_match                34 non-null     object
#  12  chebi_syn                  25 non-null     object
#  13  chebi_syn_match            25 non-null     object
#  14  chebi_match_aid            0 non-null      float64
#  15  chemid_pt                  91 non-null     object
#  16  chemid_display_name        12 non-null     object
#  17  chemid_id                  91 non-null     object
#  18  chemi_match                91 non-null     object
#  19  chemid_syn                 21 non-null     object
#  20  chemid_syn_match           21 non-null     object
#  21  chemid_match_aid           0 non-null      float64
#  22  ctd_pt                     92 non-null     object
#  23  ctd_mesh_id                92 non-null     object
#  24  ctd_cas_no                 73 non-null     object
#  25  ctd_match                  92 non-null     object
#  26  ctd_syn                    0 non-null      float64
#  27  ctd_syn_match              0 non-null      float64
#  28  ctd_match_aid              0 non-null      float64
#  29  umls_pt                    99 non-null     object
#  30  umls_cui                   99 non-null     int64
#  31  umls_match                 99 non-null     object
#  32  umls_syn                   0 non-null      float64
#  33  umls_syn_match             0 non-null      float64
#  34  umls_match_aid             0 non-null      float64
#  35  umls_sem_typ1              99 non-null     object
#  36  umls_sem_typ2              89 non-null     object
#  37  umls_sem_typ3              14 non-null     object
#  38  umls_sem_typ4              0 non-null      float64
#  39  ind_raw                    43 non-null     object
#  40  ind_agg                    18 non-null     object
#  41  ind_search                 13 non-null     object
#  42  ind_raw_value              99 non-null     object
#  43  ind_raw_target             99 non-null     object
#  44  ind_raw_match              99 non-null     bool
#  45  ind_umls_entry_term_match  99 non-null     object
#  46  ind_umls_entry_term        99 non-null     object
#  47  ind_umls_pt                99 non-null     object
#  48  und_umls_cuii              99 non-null     object
#  49  ind_umls_term_typ          99 non-null     object
#  50  ind_umls_pheno_flg         67 non-null     object
#  51  ind_umls_sem_typ1          99 non-null     object
#  52  ind_umls_sem_typ2          0 non-null      float64
#  53  ind_umls_sem_typ3          0 non-null      float64
#  54  ind_umls_sem_typ4          0 non-null      float64
#  55  ind_umls_in_term_match     62 non-null     object
#  56  ind_umls_in_term           62 non-null     object
#  57  ind_umls_in_pt             62 non-null     object
#  58  ind_umls_in_cui            62 non-null     float64
#  59  ind_umls_in_term_typ       62 non-null     object
#  60  ind_umls_in_sem_typ1       62 non-null     object
#  61  ind_umls_in_sem_typ2       9 non-null      object
#  62  ind_umls_in_sem_typ3       0 non-null      float64
#  63  ind_umls_in_sem_typ4       0 non-null      float64
# dtypes: bool(1), float64(16), int64(1), object(46)
# memory usage: 48.9+ KB

# %%
# are there any missing values
df.isnull().sum()
# Out:
# did_id                   0
# src_nm                   0
# src_id                   4
# drug_raw_name            0
# cas_cas_no              14
#                         ..
# ind_umls_in_term_typ    37
# ind_umls_in_sem_typ1    37
# ind_umls_in_sem_typ2    90
# ind_umls_in_sem_typ3    99
# ind_umls_in_sem_typ4    99
# Length: 64, dtype: int64

# %%
# how does the data look mathematically
df.describe()
# Out:
#            chebi_id  chebi_match_aid  chemid_match_aid  ctd_syn  \
# count     34.000000              0.0               0.0      0.0
# mean   50975.676471              NaN               NaN      NaN
# std    22389.321142              NaN               NaN      NaN
# min     2423.000000              NaN               NaN      NaN
# 25%    36385.000000              NaN               NaN      NaN
# 50%    52818.000000              NaN               NaN      NaN
# 75%    65164.750000              NaN               NaN      NaN
# max    81507.000000              NaN               NaN      NaN
#
#        ctd_syn_match  ctd_match_aid      umls_cui  umls_syn  umls_syn_match  \
# count            0.0            0.0  9.900000e+01       0.0             0.0
# mean             NaN            NaN  2.171806e+05       NaN             NaN
# std              NaN            NaN  5.373536e+05       NaN             NaN
# min              NaN            NaN  1.600400e+04       NaN             NaN
# 25%              NaN            NaN  4.525500e+04       NaN             NaN
# 50%              NaN            NaN  4.689900e+04       NaN             NaN
# 75%              NaN            NaN  7.642500e+04       NaN             NaN
# max              NaN            NaN  2.974024e+06       NaN             NaN
#
#        umls_match_aid  umls_sem_typ4  ind_umls_sem_typ2  ind_umls_sem_typ3  \
# count             0.0            0.0                0.0                0.0
# mean              NaN            NaN                NaN                NaN
# std               NaN            NaN                NaN                NaN
# min               NaN            NaN                NaN                NaN
# 25%               NaN            NaN                NaN                NaN
# 50%               NaN            NaN                NaN                NaN
# 75%               NaN            NaN                NaN                NaN
# max               NaN            NaN                NaN                NaN
#
#        ind_umls_sem_typ4  ind_umls_in_cui  ind_umls_in_sem_typ3  \
# count                0.0     6.200000e+01                   0.0
# mean                 NaN     1.645680e+05                   NaN
# std                  NaN     4.211118e+05                   NaN
# min                  NaN     3.204000e+03                   NaN
# 25%                  NaN     7.220000e+03                   NaN
# 50%                  NaN     2.075500e+04                   NaN
# 75%                  NaN     2.429000e+05                   NaN
# max                  NaN     2.936570e+06                   NaN
#
#        ind_umls_in_sem_typ4
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
#are there any duplicate values
df.duplicated().sum()
df
# Out:
#       did_id   src_nm    src_id                     drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157                         Fish Oils   8016-13-5
# 1   1_000002    NDFRT  C0016157                         Fish Oils   8016-13-5
# 2   1_000003    NDFRT  C0016157                         Fish Oils   8016-13-5
# 3   1_000004    NDFRT  C0016157                         Fish Oils   8016-13-5
# 4   1_000005    NDFRT  C0016157                         Fish Oils   8016-13-5
# ..       ...      ...       ...                               ...         ...
# 94  1_000095  MeSH_PA   C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 95  1_000096  MeSH_PA   C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 96  1_000097  MeSH_PA   C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 97  1_000098  MeSH_PA   C057837  3,7-dimethyl-1-propargylxanthine  14114-46-6
# 98  1_000099  MeSH_PA   C057837  3,7-dimethyl-1-propargylxanthine  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#          chebi_pt  chebi_id  ... ind_umls_sem_typ4 ind_umls_in_term_match  \
# 0             NaN       NaN  ...               NaN                    NaN
# 1             NaN       NaN  ...               NaN                    NaN
# 2             NaN       NaN  ...               NaN                    NaN
# 3             NaN       NaN  ...               NaN                    NaN
# 4             NaN       NaN  ...               NaN                    NaN
# ..            ...       ...  ...               ...                    ...
# 94  dilC18(3)(1+)   52818.0  ...               NaN                    NaN
# 95  dilC18(3)(1+)   52818.0  ...               NaN                    NaN
# 96  dilC18(3)(1+)   52818.0  ...               NaN                    NaN
# 97            NaN       NaN  ...               NaN      exact (CUI-based)
# 98            NaN       NaN  ...               NaN      exact (CUI-based)
#
#                      ind_umls_in_term                     ind_umls_in_pt  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 94                                NaN                                NaN
# 95                                NaN                                NaN
# 96                                NaN                                NaN
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_umls_in_cui ind_umls_in_term_typ                ind_umls_in_sem_typ1  \
# 0               NaN                  NaN                                 NaN
# 1               NaN                  NaN                                 NaN
# 2               NaN                  NaN                                 NaN
# 3               NaN                  NaN                                 NaN
# 4               NaN                  NaN                                 NaN
# ..              ...                  ...                                 ...
# 94              NaN                  NaN                                 NaN
# 95              NaN                  NaN                                 NaN
# 96              NaN                  NaN                                 NaN
# 97        2936570.0                    P  A1.4.1.1.1_Pharmacologic Substance
# 98         243051.0                    P  A1.4.1.1.1_Pharmacologic Substance
#
#    ind_umls_in_sem_typ2 ind_umls_in_sem_typ3 ind_umls_in_sem_typ4
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ..                  ...                  ...                  ...
# 94                  NaN                  NaN                  NaN
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
# 97                  NaN                  NaN                  NaN
# 98                  NaN                  NaN                  NaN
#
# [99 rows x 64 columns]

# %%
# from this code we can understand how many missing values in every column
df.isnull().mean()*100
# Out:
# did_id                    0.000000
# src_nm                    0.000000
# src_id                    4.040404
# drug_raw_name             0.000000
# cas_cas_no               14.141414
#                            ...
# ind_umls_in_term_typ     37.373737
# ind_umls_in_sem_typ1     37.373737
# ind_umls_in_sem_typ2     90.909091
# ind_umls_in_sem_typ3    100.000000
# ind_umls_in_sem_typ4    100.000000
# Length: 64, dtype: float64

# %%
cols =[var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]
cols
# Out:
# ['src_id']

# %%
#how many data left after  droping null values 
len(df[cols].dropna()) / len(df)
# Out:
# 0.9595959595959596

# %%
df=df.drop(['did_id','chebi_pt', 'chebi_id', 'chebi_cas_no',
       'chebi_match', 'chebi_syn', 'chebi_syn_match', 'chebi_match_aid','chemid_pt', 'chemid_display_name', 'chemid_id', 'chemi_match',
       'chemid_syn', 'chemid_syn_match', 'chemid_match_aid', 'ctd_pt',
       'ctd_mesh_id', 'ctd_cas_no', 'ctd_match', 'ctd_syn', 'ctd_syn_match',
       'ctd_match_aid','umls_match', 'umls_syn',
       'umls_syn_match', 'umls_match_aid', 'umls_sem_typ1', 'umls_sem_typ2',
       'umls_sem_typ3', 'umls_sem_typ4', 'ind_raw', 'ind_agg', 'ind_search', 'ind_umls_entry_term', 'ind_umls_pt',
       'und_umls_cuii', 'ind_umls_term_typ', 'ind_umls_pheno_flg',
       'ind_umls_sem_typ1', 'ind_umls_sem_typ2', 'ind_umls_sem_typ3',
       'ind_umls_sem_typ4', 'ind_umls_in_term_match', 'ind_umls_in_term',
       'ind_umls_in_pt', 'ind_umls_in_cui', 'ind_umls_in_term_typ',
       'ind_umls_in_sem_typ1', 'ind_umls_in_sem_typ2', 'ind_umls_in_sem_typ3',
       'ind_umls_in_sem_typ4'], axis = 1)

# %%
df
# Out:
#       did_id   src_nm    src_id                     drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157                         Fish Oils   8016-13-5
# 1   1_000002    NDFRT  C0016157                         Fish Oils   8016-13-5
# 2   1_000003    NDFRT  C0016157                         Fish Oils   8016-13-5
# 3   1_000004    NDFRT  C0016157                         Fish Oils   8016-13-5
# 4   1_000005    NDFRT  C0016157                         Fish Oils   8016-13-5
# ..       ...      ...       ...                               ...         ...
# 94  1_000095  MeSH_PA   C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 95  1_000096  MeSH_PA   C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 96  1_000097  MeSH_PA   C024286  3,3'-dioctadecylindocarbocyanine  40957-95-7
# 97  1_000098  MeSH_PA   C057837  3,7-dimethyl-1-propargylxanthine  14114-46-6
# 98  1_000099  MeSH_PA   C057837  3,7-dimethyl-1-propargylxanthine  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
# uncomment this code for generate a pandas profiling
# from pandas_profiling import ProfileReport
# prof = ProfileReport(newdata1)
# prof.to_file(output_file="output1.html")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     99 non-null     object
#  1   src_nm                     99 non-null     object
#  2   src_id                     95 non-null     object
#  3   drug_raw_name              99 non-null     object
#  4   cas_cas_no                 85 non-null     object
#  5   cas_pt                     85 non-null     object
#  6   cas_source                 85 non-null     object
#  7   cas_match                  85 non-null     object
#  8   umls_pt                    99 non-null     object
#  9   umls_cui                   99 non-null     int64
#  10  ind_raw_value              99 non-null     object
#  11  ind_raw_target             99 non-null     object
#  12  ind_raw_match              99 non-null     bool
#  13  ind_umls_entry_term_match  99 non-null     object
# dtypes: bool(1), int64(1), object(12)
# memory usage: 10.3+ KB

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (99, 14)

# %%
#newdata1['cas_cas_no'].fillna(newdata1['cas_cas_no'].mode(), inplace=True)

# %%
#newdata1.info()

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df.head()
# Out:
#      did_id src_nm    src_id drug_raw_name cas_cas_no    cas_pt cas_source  \
# 0  1_000001  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 1  1_000002  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 2  1_000003  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 3  1_000004  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
# 4  1_000005  NDFRT  C0016157     Fish Oils  8016-13-5  Fish oil    ChemID+
#
#           cas_match    umls_pt  umls_cui              ind_raw_value  \
# 0  <syn per source>  Fish Oils     16157                 Arrhythmia
# 1  <syn per source>  Fish Oils     16157      Arthritis, Rheumatoid
# 2  <syn per source>  Fish Oils     16157  Fatigue Syndrome, Chronic
# 3  <syn per source>  Fish Oils     16157             Hyperlipidemia
# 4  <syn per source>  Fish Oils     16157               Hypertension
#
#               ind_raw_target  ind_raw_match ind_umls_entry_term_match
# 0                 Arrhythmia           True         exact (CUI-based)
# 1      Arthritis, Rheumatoid           True         exact (CUI-based)
# 2  Fatigue Syndrome, Chronic           True         exact (CUI-based)
# 3             Hyperlipidemia           True         exact (CUI-based)
# 4               Hypertension           True         exact (CUI-based)

# %%
df["drug_raw_name"]=le.fit_transform(df["drug_raw_name"])

# %%
df.head()
# Out:
#      did_id src_nm    src_id  drug_raw_name cas_cas_no    cas_pt cas_source  \
# 0  1_000001  NDFRT  C0016157             25  8016-13-5  Fish oil    ChemID+
# 1  1_000002  NDFRT  C0016157             25  8016-13-5  Fish oil    ChemID+
# 2  1_000003  NDFRT  C0016157             25  8016-13-5  Fish oil    ChemID+
# 3  1_000004  NDFRT  C0016157             25  8016-13-5  Fish oil    ChemID+
# 4  1_000005  NDFRT  C0016157             25  8016-13-5  Fish oil    ChemID+
#
#           cas_match    umls_pt  umls_cui              ind_raw_value  \
# 0  <syn per source>  Fish Oils     16157                 Arrhythmia
# 1  <syn per source>  Fish Oils     16157      Arthritis, Rheumatoid
# 2  <syn per source>  Fish Oils     16157  Fatigue Syndrome, Chronic
# 3  <syn per source>  Fish Oils     16157             Hyperlipidemia
# 4  <syn per source>  Fish Oils     16157               Hypertension
#
#               ind_raw_target  ind_raw_match ind_umls_entry_term_match
# 0                 Arrhythmia           True         exact (CUI-based)
# 1      Arthritis, Rheumatoid           True         exact (CUI-based)
# 2  Fatigue Syndrome, Chronic           True         exact (CUI-based)
# 3             Hyperlipidemia           True         exact (CUI-based)
# 4               Hypertension           True         exact (CUI-based)

# %%
le.classes_
# Out:
# array(['1,5-difluoro-2,4-dinitrobenzene',
#        '1-(carboxymethylthio)tetradecane',
#        '1-O-acetyl-4R,6S-britannilactone',
#        '1-anilino-8-naphthalenesulfonate',
#        '1-hexylcarbamoyl-5-fluorouracil',
#        "2'-methyl-2'-deoxyidenecytidine",
#        '2,3,7,8-tetrachlorodibenzofuran',
#        '2,3-naphthalenedicarboxaldehyde',
#        '2,3-piperidinedicarboxylic acid',
#        '2,5-dimethoxy-4-bromoamphetamine',
#        '2-(2-benzofuranyl)-2-imidazoline',
#        '2-(methyldithio)pyridine-N-oxide',
#        '2-amino-4-phosphonobutyric acid',
#        '2-chloro-5-hydroxyphenylglycine',
#        '2-nitro-5-thiocyanobenzoic acid',
#        "3,3'-dihexadecylindocarbocyanine",
#        "3,3'-dioctadecylindocarbocyanine",
#        "3,4,5,3',4'-pentachlorobiphenyl",
#        '3,7-dimethyl-1-propargylxanthine',
#        '4-des-dimethylaminotetracycline',
#        "5-(2-iodovinyl)-2'-deoxyuridine",
#        "5-hydroxymethyl-2'-deoxyuridine",
#        '6-methoxy-2-naphthylacetic acid', 'Dietary Sucrose',
#        'Fibrin Tissue Adhesive', 'Fish Oils',
#        'S-Nitroso-N-Acetylpenicillamine',
#        'acetyl tert-butyl dimethylindan',
#        'acetylleucyl-leucyl-norleucinal',
#        'bis(3,5-dibromosalicyl)fumarate',
#        'hydrated silica gel-based toothpaste',
#        'hydrochlorothiazide-triamterene', 'organochlorine insecticide',
#        'organochlorine pesticide', 'pyrrolidine dithiocarbamic acid',
#        'thiazolidine-4-carboxylic acid'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     99 non-null     object
#  1   src_nm                     99 non-null     object
#  2   src_id                     95 non-null     object
#  3   drug_raw_name              99 non-null     int64
#  4   cas_cas_no                 85 non-null     object
#  5   cas_pt                     85 non-null     object
#  6   cas_source                 85 non-null     object
#  7   cas_match                  85 non-null     object
#  8   umls_pt                    99 non-null     object
#  9   umls_cui                   99 non-null     int64
#  10  ind_raw_value              99 non-null     object
#  11  ind_raw_target             99 non-null     object
#  12  ind_raw_match              99 non-null     bool
#  13  ind_umls_entry_term_match  99 non-null     object
# dtypes: bool(1), int64(2), object(11)
# memory usage: 10.9+ KB

# %%
# after droping the column i have create new csv file for that dataset
df.to_csv('did2.csv', index=False)

# %% [markdown]
# #  We are handling missing values in the categorical data

# %%
df=pd.read_csv("did2.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     99 non-null     object
#  1   src_nm                     99 non-null     object
#  2   src_id                     95 non-null     object
#  3   drug_raw_name              99 non-null     int64
#  4   cas_cas_no                 85 non-null     object
#  5   cas_pt                     85 non-null     object
#  6   cas_source                 85 non-null     object
#  7   cas_match                  85 non-null     object
#  8   umls_pt                    99 non-null     object
#  9   umls_cui                   99 non-null     int64
#  10  ind_raw_value              99 non-null     object
#  11  ind_raw_target             99 non-null     object
#  12  ind_raw_match              99 non-null     bool
#  13  ind_umls_entry_term_match  99 non-null     object
# dtypes: bool(1), int64(2), object(11)
# memory usage: 10.3+ KB

# %%
#df['src_id']= df['src_id'].fillna(value=df['src_id'].mode[0])

# %%
#handleing missing value in categorical value 
#lets replace the null value in the src_id coulmn

df=pd.read_csv("did2.csv")
m=df["src_id"].mode()
m
# Out:
# 0    C003943
# Name: src_id, dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["src_id"].mode()[0]
m
# Out:
# 'C003943'

# %%
# fill in the value
df["src_id"].fillna(m,inplace=True)
df
# Out:
#       did_id   src_nm    src_id  drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157             25   8016-13-5
# 1   1_000002    NDFRT  C0016157             25   8016-13-5
# 2   1_000003    NDFRT  C0016157             25   8016-13-5
# 3   1_000004    NDFRT  C0016157             25   8016-13-5
# 4   1_000005    NDFRT  C0016157             25   8016-13-5
# ..       ...      ...       ...            ...         ...
# 94  1_000095  MeSH_PA   C024286             16  40957-95-7
# 95  1_000096  MeSH_PA   C024286             16  40957-95-7
# 96  1_000097  MeSH_PA   C024286             16  40957-95-7
# 97  1_000098  MeSH_PA   C057837             18  14114-46-6
# 98  1_000099  MeSH_PA   C057837             18  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     99 non-null     object
#  1   src_nm                     99 non-null     object
#  2   src_id                     99 non-null     object
#  3   drug_raw_name              99 non-null     int64
#  4   cas_cas_no                 85 non-null     object
#  5   cas_pt                     85 non-null     object
#  6   cas_source                 85 non-null     object
#  7   cas_match                  85 non-null     object
#  8   umls_pt                    99 non-null     object
#  9   umls_cui                   99 non-null     int64
#  10  ind_raw_value              99 non-null     object
#  11  ind_raw_target             99 non-null     object
#  12  ind_raw_match              99 non-null     bool
#  13  ind_umls_entry_term_match  99 non-null     object
# dtypes: bool(1), int64(2), object(11)
# memory usage: 10.3+ KB

# %%
df.isnull().sum()
# Out:
# did_id                        0
# src_nm                        0
# src_id                        0
# drug_raw_name                 0
# cas_cas_no                   14
# cas_pt                       14
# cas_source                   14
# cas_match                    14
# umls_pt                       0
# umls_cui                      0
# ind_raw_value                 0
# ind_raw_target                0
# ind_raw_match                 0
# ind_umls_entry_term_match     0
# dtype: int64

# %% [markdown]
# #  lets work on cas_cas_no column  missing values

# %%
# df=pd.read_csv("did2.csv")
m=df["cas_cas_no"].mode()
m
# Out:
# 0    64638-07-9
# Name: cas_cas_no, dtype: object

# %%
m=df["cas_cas_no"].mode()[0]
m
# Out:
# '64638-07-9'

# %%
# fill in the value
df["cas_cas_no"].fillna(m,inplace=True)
df
# Out:
#       did_id   src_nm    src_id  drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157             25   8016-13-5
# 1   1_000002    NDFRT  C0016157             25   8016-13-5
# 2   1_000003    NDFRT  C0016157             25   8016-13-5
# 3   1_000004    NDFRT  C0016157             25   8016-13-5
# 4   1_000005    NDFRT  C0016157             25   8016-13-5
# ..       ...      ...       ...            ...         ...
# 94  1_000095  MeSH_PA   C024286             16  40957-95-7
# 95  1_000096  MeSH_PA   C024286             16  40957-95-7
# 96  1_000097  MeSH_PA   C024286             16  40957-95-7
# 97  1_000098  MeSH_PA   C057837             18  14114-46-6
# 98  1_000099  MeSH_PA   C057837             18  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# did_id                        0
# src_nm                        0
# src_id                        0
# drug_raw_name                 0
# cas_cas_no                    0
# cas_pt                       14
# cas_source                   14
# cas_match                    14
# umls_pt                       0
# umls_cui                      0
# ind_raw_value                 0
# ind_raw_target                0
# ind_raw_match                 0
# ind_umls_entry_term_match     0
# dtype: int64

# %%
#lets work on cas_pt column missing value

# %%
df.isnull().sum()
# Out:
# did_id                        0
# src_nm                        0
# src_id                        0
# drug_raw_name                 0
# cas_cas_no                    0
# cas_pt                       14
# cas_source                   14
# cas_match                    14
# umls_pt                       0
# umls_cui                      0
# ind_raw_value                 0
# ind_raw_target                0
# ind_raw_match                 0
# ind_umls_entry_term_match     0
# dtype: int64

# %%
m2=df["cas_pt"].mode()
m2
# Out:
# 0    Brolamfetamine
# Name: cas_pt, dtype: object

# %%
m1=df["cas_pt"].mode()[0]
m1
# Out:
# 'Brolamfetamine'

# %%
df["cas_pt"].fillna(m,inplace=True)
df
# Out:
#       did_id   src_nm    src_id  drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157             25   8016-13-5
# 1   1_000002    NDFRT  C0016157             25   8016-13-5
# 2   1_000003    NDFRT  C0016157             25   8016-13-5
# 3   1_000004    NDFRT  C0016157             25   8016-13-5
# 4   1_000005    NDFRT  C0016157             25   8016-13-5
# ..       ...      ...       ...            ...         ...
# 94  1_000095  MeSH_PA   C024286             16  40957-95-7
# 95  1_000096  MeSH_PA   C024286             16  40957-95-7
# 96  1_000097  MeSH_PA   C024286             16  40957-95-7
# 97  1_000098  MeSH_PA   C057837             18  14114-46-6
# 98  1_000099  MeSH_PA   C057837             18  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
# lets work on cas_source  data column 
# handleing missing value

# %%
m3=df["cas_source"].mode()
m3
# Out:
# 0    ChemID+
# Name: cas_source, dtype: object

# %%
m1=df["cas_source"].mode()[0]
m1
# Out:
# 'ChemID+'

# %%
df["cas_source"].fillna(m,inplace=True)
df
# Out:
#       did_id   src_nm    src_id  drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157             25   8016-13-5
# 1   1_000002    NDFRT  C0016157             25   8016-13-5
# 2   1_000003    NDFRT  C0016157             25   8016-13-5
# 3   1_000004    NDFRT  C0016157             25   8016-13-5
# 4   1_000005    NDFRT  C0016157             25   8016-13-5
# ..       ...      ...       ...            ...         ...
# 94  1_000095  MeSH_PA   C024286             16  40957-95-7
# 95  1_000096  MeSH_PA   C024286             16  40957-95-7
# 96  1_000097  MeSH_PA   C024286             16  40957-95-7
# 97  1_000098  MeSH_PA   C057837             18  14114-46-6
# 98  1_000099  MeSH_PA   C057837             18  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
# lets work on cas_match  column

# %%
m4=df["cas_match"].mode()
m4
# Out:
# 0    exact
# Name: cas_match, dtype: object

# %%
m4=df["cas_match"].mode()[0]
m4
# Out:
# 'exact'

# %%
df["cas_match"].fillna(m,inplace=True)
df
# Out:
#       did_id   src_nm    src_id  drug_raw_name  cas_cas_no  \
# 0   1_000001    NDFRT  C0016157             25   8016-13-5
# 1   1_000002    NDFRT  C0016157             25   8016-13-5
# 2   1_000003    NDFRT  C0016157             25   8016-13-5
# 3   1_000004    NDFRT  C0016157             25   8016-13-5
# 4   1_000005    NDFRT  C0016157             25   8016-13-5
# ..       ...      ...       ...            ...         ...
# 94  1_000095  MeSH_PA   C024286             16  40957-95-7
# 95  1_000096  MeSH_PA   C024286             16  40957-95-7
# 96  1_000097  MeSH_PA   C024286             16  40957-95-7
# 97  1_000098  MeSH_PA   C057837             18  14114-46-6
# 98  1_000099  MeSH_PA   C057837             18  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     99 non-null     object
#  1   src_nm                     99 non-null     object
#  2   src_id                     99 non-null     object
#  3   drug_raw_name              99 non-null     int64
#  4   cas_cas_no                 99 non-null     object
#  5   cas_pt                     99 non-null     object
#  6   cas_source                 99 non-null     object
#  7   cas_match                  99 non-null     object
#  8   umls_pt                    99 non-null     object
#  9   umls_cui                   99 non-null     int64
#  10  ind_raw_value              99 non-null     object
#  11  ind_raw_target             99 non-null     object
#  12  ind_raw_match              99 non-null     bool
#  13  ind_umls_entry_term_match  99 non-null     object
# dtypes: bool(1), int64(2), object(11)
# memory usage: 10.3+ KB

# %%
df.tail(20)
# Out:
#       did_id   src_nm   src_id  drug_raw_name  cas_cas_no  \
# 79  1_000080  MeSH_PA  C103723             10  72583-92-7
# 80  1_000081  MeSH_PA  C103723             10  72583-92-7
# 81  1_000082    ChEBI  C003943             11  64638-07-9
# 82  1_000083  MeSH_PA  C003943              9  64638-07-9
# 83  1_000084  MeSH_PA  C003943              9  64638-07-9
# 84  1_000085  MeSH_PA  C003943              9  64638-07-9
# 85  1_000086  MeSH_PA  C003943              9  64638-07-9
# 86  1_000087  MeSH_PA  C003943              9  64638-07-9
# 87  1_000088  MeSH_PA  C003943              9  64638-07-9
# 88  1_000089  MeSH_PA  C035005             15  64638-07-9
# 89  1_000090  MeSH_PA  C035005             15  64638-07-9
# 90  1_000091  MeSH_PA  C035005             15  64638-07-9
# 91  1_000092  MeSH_PA  C035005             15  64638-07-9
# 92  1_000093  MeSH_PA  C024286             16  40957-95-7
# 93  1_000094  MeSH_PA  C024286             16  40957-95-7
# 94  1_000095  MeSH_PA  C024286             16  40957-95-7
# 95  1_000096  MeSH_PA  C024286             16  40957-95-7
# 96  1_000097  MeSH_PA  C024286             16  40957-95-7
# 97  1_000098  MeSH_PA  C057837             18  14114-46-6
# 98  1_000099  MeSH_PA  C057837             18  14114-46-6
#
#                               cas_pt  cas_source         cas_match  \
# 79  2-(2-Benzofuranyl)-2-imidazoline     ChemID+             exact
# 80  2-(2-Benzofuranyl)-2-imidazoline     ChemID+             exact
# 81                        64638-07-9  64638-07-9        64638-07-9
# 82                    Brolamfetamine     ChemID+  <syn per source>
# 83                    Brolamfetamine     ChemID+  <syn per source>
# 84                    Brolamfetamine     ChemID+  <syn per source>
# 85                    Brolamfetamine     ChemID+  <syn per source>
# 86                    Brolamfetamine     ChemID+  <syn per source>
# 87                    Brolamfetamine     ChemID+  <syn per source>
# 88                        64638-07-9  64638-07-9        64638-07-9
# 89                        64638-07-9  64638-07-9        64638-07-9
# 90                        64638-07-9  64638-07-9        64638-07-9
# 91                        64638-07-9  64638-07-9        64638-07-9
# 92  3,3'-Dioctadecylindocarbocyanine     ChemID+             exact
# 93  3,3'-Dioctadecylindocarbocyanine     ChemID+             exact
# 94  3,3'-Dioctadecylindocarbocyanine     ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine     ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine     ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine     ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine     ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 79  2-(2-Benzofuranyl)-2-Imidazoline    534468
# 80  2-(2-Benzofuranyl)-2-Imidazoline    534468
# 81  2-(Methyldithio)Pyridine-N-Oxide   2933174
# 82  2,5-Dimethoxy-4-Bromoamphetamine     45561
# 83  2,5-Dimethoxy-4-Bromoamphetamine     45561
# 84  2,5-Dimethoxy-4-Bromoamphetamine     45561
# 85  2,5-Dimethoxy-4-Bromoamphetamine     45561
# 86  2,5-Dimethoxy-4-Bromoamphetamine     45561
# 87  2,5-Dimethoxy-4-Bromoamphetamine     45561
# 88  3,3'-Dihexadecylindocarbocyanine     46893
# 89  3,3'-Dihexadecylindocarbocyanine     46893
# 90  3,3'-Dihexadecylindocarbocyanine     46893
# 91  3,3'-Dihexadecylindocarbocyanine     46893
# 92  3,3'-Dioctadecylindocarbocyanine     46899
# 93  3,3'-Dioctadecylindocarbocyanine     46899
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 79                    Affinity Labels                    Affinity Labels
# 80            Indicators and Reagents            Indicators and Reagents
# 81                antibacterial agent                antibacterial agent
# 82      Central Nervous System Agents      Central Nervous System Agents
# 83                      Hallucinogens                      Hallucinogens
# 84            Neurotransmitter Agents            Neurotransmitter Agents
# 85                 Psychotropic Drugs                 Psychotropic Drugs
# 86                   Serotonin Agents                   Serotonin Agents
# 87        Serotonin Receptor Agonists        Serotonin Receptor Agonists
# 88                    Coloring Agents                    Coloring Agents
# 89                   Fluorescent Dyes                   Fluorescent Dyes
# 90            Indicators and Reagents            Indicators and Reagents
# 91                 Luminescent Agents                 Luminescent Agents
# 92                    Affinity Labels                    Affinity Labels
# 93                    Coloring Agents                    Coloring Agents
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 79           True                     exact (CUI-based)
# 80           True                     exact (CUI-based)
# 81           True        quasi syn therclass-to-disease
# 82           True        quasi syn therclass-to-disease
# 83           True       quasi syn therclass-to-function
# 84           True       quasi syn therclass-to-function
# 85           True        quasi syn therclass-to-disease
# 86           True       quasi syn therclass-to-function
# 87           True       quasi syn therclass-to-function
# 88           True                     exact (CUI-based)
# 89           True                     exact (CUI-based)
# 90           True                     exact (CUI-based)
# 91           True                     exact (CUI-based)
# 92           True                     exact (CUI-based)
# 93           True                     exact (CUI-based)
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function

# %%
df.shape
# Out:
# (99, 14)

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df["src_nm"]=le.fit_transform(df["src_nm"])

# %%
df.head()
# Out:
#      did_id  src_nm    src_id  drug_raw_name cas_cas_no    cas_pt cas_source  \
# 0  1_000001       2  C0016157             25  8016-13-5  Fish oil    ChemID+
# 1  1_000002       2  C0016157             25  8016-13-5  Fish oil    ChemID+
# 2  1_000003       2  C0016157             25  8016-13-5  Fish oil    ChemID+
# 3  1_000004       2  C0016157             25  8016-13-5  Fish oil    ChemID+
# 4  1_000005       2  C0016157             25  8016-13-5  Fish oil    ChemID+
#
#           cas_match    umls_pt  umls_cui              ind_raw_value  \
# 0  <syn per source>  Fish Oils     16157                 Arrhythmia
# 1  <syn per source>  Fish Oils     16157      Arthritis, Rheumatoid
# 2  <syn per source>  Fish Oils     16157  Fatigue Syndrome, Chronic
# 3  <syn per source>  Fish Oils     16157             Hyperlipidemia
# 4  <syn per source>  Fish Oils     16157               Hypertension
#
#               ind_raw_target  ind_raw_match ind_umls_entry_term_match
# 0                 Arrhythmia           True         exact (CUI-based)
# 1      Arthritis, Rheumatoid           True         exact (CUI-based)
# 2  Fatigue Syndrome, Chronic           True         exact (CUI-based)
# 3             Hyperlipidemia           True         exact (CUI-based)
# 4               Hypertension           True         exact (CUI-based)

# %%
df["src_id"]=le.fit_transform(df["src_id"])

# %%
df.head()
# Out:
#      did_id  src_nm  src_id  drug_raw_name cas_cas_no    cas_pt cas_source  \
# 0  1_000001       2       0             25  8016-13-5  Fish oil    ChemID+
# 1  1_000002       2       0             25  8016-13-5  Fish oil    ChemID+
# 2  1_000003       2       0             25  8016-13-5  Fish oil    ChemID+
# 3  1_000004       2       0             25  8016-13-5  Fish oil    ChemID+
# 4  1_000005       2       0             25  8016-13-5  Fish oil    ChemID+
#
#           cas_match    umls_pt  umls_cui              ind_raw_value  \
# 0  <syn per source>  Fish Oils     16157                 Arrhythmia
# 1  <syn per source>  Fish Oils     16157      Arthritis, Rheumatoid
# 2  <syn per source>  Fish Oils     16157  Fatigue Syndrome, Chronic
# 3  <syn per source>  Fish Oils     16157             Hyperlipidemia
# 4  <syn per source>  Fish Oils     16157               Hypertension
#
#               ind_raw_target  ind_raw_match ind_umls_entry_term_match
# 0                 Arrhythmia           True         exact (CUI-based)
# 1      Arthritis, Rheumatoid           True         exact (CUI-based)
# 2  Fatigue Syndrome, Chronic           True         exact (CUI-based)
# 3             Hyperlipidemia           True         exact (CUI-based)
# 4               Hypertension           True         exact (CUI-based)

# %%
data=df

# %%
data
# Out:
#       did_id  src_nm  src_id  drug_raw_name  cas_cas_no  \
# 0   1_000001       2       0             25   8016-13-5
# 1   1_000002       2       0             25   8016-13-5
# 2   1_000003       2       0             25   8016-13-5
# 3   1_000004       2       0             25   8016-13-5
# 4   1_000005       2       0             25   8016-13-5
# ..       ...     ...     ...            ...         ...
# 94  1_000095       1      13             16  40957-95-7
# 95  1_000096       1      13             16  40957-95-7
# 96  1_000097       1      13             16  40957-95-7
# 97  1_000098       1      23             18  14114-46-6
# 98  1_000099       1      23             18  14114-46-6
#
#                               cas_pt cas_source         cas_match  \
# 0                           Fish oil    ChemID+  <syn per source>
# 1                           Fish oil    ChemID+  <syn per source>
# 2                           Fish oil    ChemID+  <syn per source>
# 3                           Fish oil    ChemID+  <syn per source>
# 4                           Fish oil    ChemID+  <syn per source>
# ..                               ...        ...               ...
# 94  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 95  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 96  3,3'-Dioctadecylindocarbocyanine    ChemID+             exact
# 97  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
# 98  3,7-Dimethyl-1-propargylxanthine    ChemID+             exact
#
#                              umls_pt  umls_cui  \
# 0                          Fish Oils     16157
# 1                          Fish Oils     16157
# 2                          Fish Oils     16157
# 3                          Fish Oils     16157
# 4                          Fish Oils     16157
# ..                               ...       ...
# 94  3,3'-Dioctadecylindocarbocyanine     46899
# 95  3,3'-Dioctadecylindocarbocyanine     46899
# 96  3,3'-Dioctadecylindocarbocyanine     46899
# 97  3,7-Dimethyl-1-Propargylxanthine    165153
# 98  3,7-Dimethyl-1-Propargylxanthine    165153
#
#                         ind_raw_value                     ind_raw_target  \
# 0                          Arrhythmia                         Arrhythmia
# 1               Arthritis, Rheumatoid              Arthritis, Rheumatoid
# 2           Fatigue Syndrome, Chronic          Fatigue Syndrome, Chronic
# 3                      Hyperlipidemia                     Hyperlipidemia
# 4                        Hypertension                       Hypertension
# ..                                ...                                ...
# 94                   Fluorescent Dyes                   Fluorescent Dyes
# 95            Indicators and Reagents            Indicators and Reagents
# 96                 Luminescent Agents                 Luminescent Agents
# 97  Adenosine A2 Receptor Antagonists  Adenosine A2 Receptor Antagonists
# 98            Neurotransmitter Agents            Neurotransmitter Agents
#
#     ind_raw_match             ind_umls_entry_term_match
# 0            True                     exact (CUI-based)
# 1            True                     exact (CUI-based)
# 2            True                     exact (CUI-based)
# 3            True                     exact (CUI-based)
# 4            True                     exact (CUI-based)
# ..            ...                                   ...
# 94           True                     exact (CUI-based)
# 95           True                     exact (CUI-based)
# 96           True                     exact (CUI-based)
# 97           True  NT + quasi syn therclass-to-function
# 98           True       quasi syn therclass-to-function
#
# [99 rows x 14 columns]

# %%
pip install pandas profiling
# Out:
# Requirement already satisfied: pandas in /home/dte/.local/lib/python3.8/site-packages (1.4.1)
# Requirement already satisfied: profiling in /home/dte/.local/lib/python3.8/site-packages (0.1.3)
# Requirement already satisfied: pytz>=2020.1 in /home/dte/.local/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /home/dte/.local/lib/python3.8/site-packages (from pandas) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/dte/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: valuedispatch>=0.0.1 in /home/dte/.local/lib/python3.8/site-packages (from profiling) (0.0.1)
# Requirement already satisfied: click>=4.1 in /usr/lib/python3/dist-packages (from profiling) (7.0)
# Requirement already satisfied: six>=1.8.0 in /usr/lib/python3/dist-packages (from profiling) (1.14.0)
# Requirement already satisfied: click-default-group>=1.2 in /home/dte/.local/lib/python3.8/site-packages (from profiling) (1.2.2)
# Requirement already satisfied: urwid>=1.2.1 in /home/dte/.local/lib/python3.8/site-packages (from profiling) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#after cleaning sample data report

import pandas_profiling
from pandas_profiling import ProfileReport

# %%
#creating a report after cleaning sample data
Profile = ProfileReport(data)

# %%
profile.to_file(output_file = "sample.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-398-08479f17a83b> in <module>
# ----> 1 profile.to_file(output_file = "sample.html")
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_file(self, output_file, silent)
#     255                 create_html_assets(self.config, output_file)
#     256
# --> 257             data = self.to_html()
#     258
#     259             if output_file.suffix != ".html":
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     366
#     367         """
# --> 368         return self.html
#     369
#     370     def to_json(self) -> str:
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in html(self)
#     183     def html(self) -> str:
#     184         if self._html is None:
# --> 185             self._html = self._render_html()
#     186         return self._html
#     187
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in _render_html(self)
#     285         from pandas_profiling.report.presentation.flavours import HTMLReport
#     286
# --> 287         report = self.report
#     288
#     289         with tqdm(
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in report(self)
#     177     def report(self) -> Root:
#     178         if self._report is None:
# --> 179             self._report = get_report_structure(self.config, self.description_set)
#     180         return self._report
#     181
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in description_set(self)
#     159     def description_set(self) -> Dict[str, Any]:
#     160         if self._description_set is None:
# --> 161             self._description_set = describe_df(
#     162                 self.config,
#     163                 self.df,
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/describe.py in describe(config, df, summarizer, typeset, sample)
#      69         # Variable-specific
#      70         pbar.total += len(df.columns)
# ---> 71         series_description = get_series_descriptions(
#      72             config, df, summarizer, typeset, pbar
#      73         )
#
# ~/.local/lib/python3.8/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     298         func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     299         try:
# --> 300             return func(*args, **kwargs)
#     301         except TypeError as ex:
#     302             raise DispatchError(f"Function {func.__code__}") from ex
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/summary_pandas.py in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      90         # TODO: use `Pool` for Linux-based systems
#      91         with multiprocessing.pool.ThreadPool(pool_size) as executor:
# ---> 92             for i, (column, description) in enumerate(
#      93                 executor.imap_unordered(multiprocess_1d, args)
#      94             ):
#
# /usr/lib/python3.8/multiprocessing/pool.py in next(self, timeout)
#     866         if success:
#     867             return value
# --> 868         raise value
#     869
#     870     __next__ = next                    # XXX
#
# /usr/lib/python3.8/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/summary_pandas.py in multiprocess_1d(args)
#      70         """
#      71         column, series = args
# ---> 72         return column, describe_1d(config, series, summarizer, typeset)
#      73
#      74     pool_size = config.pool_size
#
# ~/.local/lib/python3.8/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     298         func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     299         try:
# --> 300             return func(*args, **kwargs)
#     301         except TypeError as ex:
#     302             raise DispatchError(f"Function {func.__code__}") from ex
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/summary_pandas.py in pandas_describe_1d(config, series, summarizer, typeset)
#      48         vtype = typeset.detect_type(series)
#      49
# ---> 50     return summarizer.summarize(config, series, dtype=vtype)
#      51
#      52
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/summarizer.py in summarize(self, config, series, dtype)
#      35             object:
#      36         """
# ---> 37         _, _, summary = self.handle(str(dtype), config, series, {"type": str(dtype)})
#      38         return summary
#      39
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/handler.py in handle(self, dtype, *args, **kwargs)
#      60         funcs = self.mapping.get(dtype, [])
#      61         op = compose(funcs)
# ---> 62         return op(*args)
#      63
#      64
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/handler.py in func2(*x)
#      19                 return f(*x)
#      20             else:
# ---> 21                 return f(*res)
#      22
#      23         return func2
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/handler.py in func2(*x)
#      19                 return f(*x)
#      20             else:
# ---> 21                 return f(*res)
#      22
#      23         return func2
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/handler.py in func2(*x)
#      19                 return f(*x)
#      20             else:
# ---> 21                 return f(*res)
#      22
#      23         return func2
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/handler.py in func2(*x)
#      15     def func(f: Callable, g: Callable) -> Callable:
#      16         def func2(*x) -> Any:
# ---> 17             res = g(*x)
#      18             if type(res) == bool:
#      19                 return f(*x)
#
# ~/.local/lib/python3.8/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     298         func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     299         try:
# --> 300             return func(*args, **kwargs)
#     301         except TypeError as ex:
#     302             raise DispatchError(f"Function {func.__code__}") from ex
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/summary_algorithms.py in inner(config, series, summary)
#      63         if not summary["hashable"]:
#      64             return config, series, summary
# ---> 65         return fn(config, series, summary)
#      66
#      67     return inner
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/summary_algorithms.py in inner(config, series, summary)
#      80             series = series.dropna()
#      81
# ---> 82         return fn(config, series, summary)
#      83
#      84     return inner
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/describe_categorical_pandas.py in pandas_describe_categorical_1d(config, series, summary)
#     203
#     204     if config.vars.cat.length:
# --> 205         summary.update(length_summary_vc(value_counts))
#     206         summary.update(
#     207             histogram_compute(
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/describe_categorical_pandas.py in length_summary_vc(vc)
#     160         "max_length": np.max(length_counts.index),
#     161         "mean_length": np.average(length_counts.index, weights=length_counts.values),
# --> 162         "median_length": weighted_median(
#     163             length_counts.index.values, weights=length_counts.values
#     164         ),
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/utils_pandas.py in weighted_median(data, weights)
#      11     midpoint = 0.5 * sum(s_weights)
#      12     if any(weights > midpoint):
# ---> 13         w_median = (data[weights == np.max(weights)])[0]
#      14     else:
#      15         cs_weights = np.cumsum(s_weights)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
