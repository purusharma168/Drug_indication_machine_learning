# %%
import pandas as pd #import pandas for dataframe operations
import numpy as np #import numpy for numerical operation
import matplotlib.pyplot as plt #import pyplot module of matplotlib
import seaborn as sns #import seaborn
#to make all plots to be displayed just below the code.
# %matplotlib inline

# %%
df= pd.read_csv("did.csv")
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (14,21,26,27,28,34,38,40,41,44,53,54,61,62,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df=  df.sample(6000)

# %%
df
# Out:
#           did_id    src_nm   src_id            drug_raw_name    cas_cas_no  \
# 97244   2_037387  evoc_ATC    A03AB               atromepine      428-07-9
# 116312  2_062985       CTD  D000305  Adrenal Cortex Hormones     8001-02-3
# 140710  2_087383       CTD  C076946                donepezil   120014-06-4
# 18991   1_021049  DrugBank  DB01091               Butenafine   101828-21-1
# 115923  2_062596       CTD  D015250              Aclarubicin    57576-44-0
# ...          ...       ...      ...                      ...           ...
# 129726  2_076399       CTD  D002740           Chlorothiazide       58-94-6
# 159889  2_106562       CTD  D008712              Methicillin       61-32-5
# 186062  2_132735       CTD  D013827            Thiabendazole      148-79-8
# 163255  2_109928       CTD  C048833                modafinil    68693-11-8
# 91310   2_031452    WHO_DD    L01XC              SAMALIZUMAB  1073059-33-2
#
# ...

# %%
df.shape
# Out:
# (6000, 64)

# %%
df.head()
# Out:
#           did_id    src_nm   src_id            drug_raw_name   cas_cas_no  \
# 97244   2_037387  evoc_ATC    A03AB               atromepine     428-07-9
# 116312  2_062985       CTD  D000305  Adrenal Cortex Hormones    8001-02-3
# 140710  2_087383       CTD  C076946                donepezil  120014-06-4
# 18991   1_021049  DrugBank  DB01091               Butenafine  101828-21-1
# 115923  2_062596       CTD  D015250              Aclarubicin   57576-44-0
#
#                  cas_pt cas_source         cas_match                chebi_pt  \
# 97244        Atromepine    ChemID+             exact                     NaN
# 116312  Corticosteroids    ChemID+  <syn per source>  corticosteroid hormone
# 140710        Donepezil    ChemID+             exact               donepezil
# 18991        Butenafine    ChemID+             exact              butenafine
# 115923      Aclarubicin    ChemID+             exact         aclacinomycin A
#
# ...

# %%
# i have used chunks of the data
df = pd.read_csv("did.csv", nrows=6000)

# %%
df.shape
# Out:
# (6000, 64)

# %%
df.head(20)
# Out:
#       did_id   src_nm    src_id                         drug_raw_name  \
# 0   1_000001    NDFRT  C0016157                             Fish Oils
# 1   1_000002    NDFRT  C0016157                             Fish Oils
# 2   1_000003    NDFRT  C0016157                             Fish Oils
# 3   1_000004    NDFRT  C0016157                             Fish Oils
# 4   1_000005    NDFRT  C0016157                             Fish Oils
# 5   1_000006  MeSH_PA   D015718                Fibrin Tissue Adhesive
# 6   1_000007  MeSH_PA   D015718                Fibrin Tissue Adhesive
# 7   1_000008  MeSH_PA   D015718                Fibrin Tissue Adhesive
# 8   1_000009  MeSH_PA   D015718                Fibrin Tissue Adhesive
# 9   1_000010  MeSH_PA   D015718                Fibrin Tissue Adhesive
# 10  1_000011    ChEBI       NaN            organochlorine insecticide
# 11  1_000012    ChEBI       NaN              organochlorine pesticide
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 64 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   did_id                     6000 non-null   object
#  1   src_nm                     6000 non-null   object
#  2   src_id                     4992 non-null   object
#  3   drug_raw_name              6000 non-null   object
#  4   cas_cas_no                 5629 non-null   object
#  5   cas_pt                     5629 non-null   object
#  6   cas_source                 5629 non-null   object
#  7   cas_match                  5629 non-null   object
#  8   chebi_pt                   2612 non-null   object
#  9   chebi_id                   2612 non-null   float64
#  10  chebi_cas_no               2322 non-null   object
#  11  chebi_match                2612 non-null   object
#  12  chebi_syn                  828 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['did_id', 'src_nm', 'src_id', 'drug_raw_name', 'cas_cas_no', 'cas_pt',
#        'cas_source', 'cas_match', 'chebi_pt', 'chebi_id', 'chebi_cas_no',
#        'chebi_match', 'chebi_syn', 'chebi_syn_match', 'chebi_match_aid',
#        'chemid_pt', 'chemid_display_name', 'chemid_id', 'chemi_match',
#        'chemid_syn', 'chemid_syn_match', 'chemid_match_aid', 'ctd_pt',
#        'ctd_mesh_id', 'ctd_cas_no', 'ctd_match', 'ctd_syn', 'ctd_syn_match',
#        'ctd_match_aid', 'umls_pt', 'umls_cui', 'umls_match', 'umls_syn',
#        'umls_syn_match', 'umls_match_aid', 'umls_sem_typ1', 'umls_sem_typ2',
#        'umls_sem_typ3', 'umls_sem_typ4', 'ind_raw', 'ind_agg', 'ind_search',
#        'ind_raw_value', 'ind_raw_target', 'ind_raw_match',
#        'ind_umls_entry_term_match', 'ind_umls_entry_term', 'ind_umls_pt',
#        'und_umls_cuii', 'ind_umls_term_typ', 'ind_umls_pheno_flg',
#        'ind_umls_sem_typ1', 'ind_umls_sem_typ2', 'ind_umls_sem_typ3',
# ...

# %%
#are there any duplicate values
df.duplicated().sum()
df
# Out:
#         did_id   src_nm    src_id  \
# 0     1_000001    NDFRT  C0016157
# 1     1_000002    NDFRT  C0016157
# 2     1_000003    NDFRT  C0016157
# 3     1_000004    NDFRT  C0016157
# 4     1_000005    NDFRT  C0016157
# ...        ...      ...       ...
# 5995  1_006391  USAN_TC       NaN
# 5996  1_006392  USAN_TC      1994
# 5997  1_006393  USAN_TC      1986
# 5998  1_006394  MeSH_PA   C025086
# 5999  1_006395  MeSH_PA   C025086
#
#                                        drug_raw_name   cas_cas_no  \
# 0                                          Fish Oils    8016-13-5
# 1                                          Fish Oils    8016-13-5
# 2                                          Fish Oils    8016-13-5
# 3                                          Fish Oils    8016-13-5
# 4                                          Fish Oils    8016-13-5
# ...                                              ...          ...
# 5995                            edrophonium chloride     116-38-1
# ...

# %%
df=df.drop(['did_id','chebi_pt', 'chebi_id', 'chebi_cas_no',
       'chebi_match', 'chebi_syn', 'chebi_syn_match', 'chebi_match_aid','chemid_pt', 'chemid_display_name', 'chemid_id', 'chemi_match',
       'chemid_syn', 'chemid_syn_match', 'chemid_match_aid', 'ctd_pt',
       'ctd_mesh_id', 'ctd_cas_no', 'ctd_match', 'ctd_syn', 'ctd_syn_match',
       'ctd_match_aid','umls_match', 'umls_syn',
       'umls_syn_match', 'umls_match_aid', 'umls_sem_typ1', 'umls_sem_typ2',
       'umls_sem_typ3', 'umls_sem_typ4', 'ind_raw', 'ind_agg', 'ind_search', 'ind_umls_entry_term', 'ind_umls_pt',
       'und_umls_cuii', 'ind_umls_term_typ', 'ind_umls_pheno_flg',
       'ind_umls_sem_typ1', 'ind_umls_sem_typ2', 'ind_umls_sem_typ3',
       'ind_umls_sem_typ4', 'ind_umls_in_term_match', 'ind_umls_in_term',
       'ind_umls_in_pt', 'ind_umls_in_cui', 'ind_umls_in_term_typ',
       'ind_umls_in_sem_typ1', 'ind_umls_in_sem_typ2', 'ind_umls_in_sem_typ3',
       'ind_umls_in_sem_typ4'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     4992 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 5629 non-null   object
#  4   cas_pt                     5629 non-null   object
#  5   cas_source                 5629 non-null   object
#  6   cas_match                  5629 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              4792 non-null   object
#  12  ind_umls_entry_term_match  6000 non-null   object
# dtypes: int64(1), object(12)
# ...

# %%
# how many missing values in this dataset
df.isnull().sum()
# Out:
# src_nm                          0
# src_id                       1008
# drug_raw_name                   0
# cas_cas_no                    371
# cas_pt                        371
# cas_source                    371
# cas_match                     371
# umls_pt                         0
# umls_cui                        0
# ind_raw_value                   0
# ind_raw_target                  0
# ind_raw_match                1208
# ind_umls_entry_term_match       0
# dtype: int64

# %%
# missing values handel

# %%
m=df["src_id"].mode()
m
# Out:
# 0    1987
# dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["src_id"].mode()[0]
m
# Out:
# '1987'

# %%
# fill in the value
df["src_id"].fillna(m,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     6000 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 5629 non-null   object
#  4   cas_pt                     5629 non-null   object
#  5   cas_source                 5629 non-null   object
#  6   cas_match                  5629 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              4792 non-null   object
#  12  ind_umls_entry_term_match  6000 non-null   object
# dtypes: int64(1), object(12)
# ...

# %%
#lets replace the null value in the cas_cas_no coulmn¶

# %%
m=df["cas_cas_no"].mode()
m
# Out:
# 0    144-55-8
# dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["cas_cas_no"].mode()[0]
m
# Out:
# '144-55-8'

# %%
# fill in the value
df["cas_cas_no"].fillna(m,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     6000 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 6000 non-null   object
#  4   cas_pt                     5629 non-null   object
#  5   cas_source                 5629 non-null   object
#  6   cas_match                  5629 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              4792 non-null   object
#  12  ind_umls_entry_term_match  6000 non-null   object
# dtypes: int64(1), object(12)
# ...

# %%
#lets replace the null value in the cas_pt coulmn
m=df["cas_pt"].mode()
m
# Out:
# 0    Sodium bicarbonate
# dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["cas_pt"].mode()[0]
m
# Out:
# 'Sodium bicarbonate'

# %%
# fill in the value
df["cas_pt"].fillna(m,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     6000 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 6000 non-null   object
#  4   cas_pt                     6000 non-null   object
#  5   cas_source                 5629 non-null   object
#  6   cas_match                  5629 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              4792 non-null   object
#  12  ind_umls_entry_term_match  6000 non-null   object
# dtypes: int64(1), object(12)
# ...

# %%
#lets replace the null value in the cas_source coulmn¶

# %%
m=df["cas_source"].mode()
m
# Out:
# 0    ChemID+
# dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["cas_source"].mode()[0]
m
# Out:
# 'ChemID+'

# %%
# fill in the value
df["cas_source"].fillna(m,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     6000 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 6000 non-null   object
#  4   cas_pt                     6000 non-null   object
#  5   cas_source                 6000 non-null   object
#  6   cas_match                  5629 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              4792 non-null   object
#  12  ind_umls_entry_term_match  6000 non-null   object
# dtypes: int64(1), object(12)
# ...

# %%
#lets replace the null value in the cas_match coulmn¶

# %%
m=df["cas_match"].mode()
m
# Out:
# 0    exact
# dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["cas_match"].mode()[0]
m
# Out:
# 'exact'

# %%
# fill in the value
df["cas_match"].fillna(m,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     6000 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 6000 non-null   object
#  4   cas_pt                     6000 non-null   object
#  5   cas_source                 6000 non-null   object
#  6   cas_match                  6000 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              4792 non-null   object
#  12  ind_umls_entry_term_match  6000 non-null   object
# dtypes: int64(1), object(12)
# ...

# %%
# lets replace the null value in the ind_raw_match coulmn

# %%
m=df["ind_raw_match"].mode()
m
# Out:
# 0    True
# dtype: object

# %%
#it returns a series object,conatining the most common value,we have to select the particular value in the series
m=df["ind_raw_match"].mode()[0]
m
# Out:
# True

# %%
# fill in the value
df["ind_raw_match"].fillna(m,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   src_nm                     6000 non-null   object
#  1   src_id                     6000 non-null   object
#  2   drug_raw_name              6000 non-null   object
#  3   cas_cas_no                 6000 non-null   object
#  4   cas_pt                     6000 non-null   object
#  5   cas_source                 6000 non-null   object
#  6   cas_match                  6000 non-null   object
#  7   umls_pt                    6000 non-null   object
#  8   umls_cui                   6000 non-null   int64
#  9   ind_raw_value              6000 non-null   object
#  10  ind_raw_target             6000 non-null   object
#  11  ind_raw_match              6000 non-null   bool
#  12  ind_umls_entry_term_match  6000 non-null   object
# ...

# %%
#all missing data is filled now lets implement label encoding on input variable

# %%
df.shape
# Out:
# (6000, 13)

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df["src_nm"]=le.fit_transform(df["src_nm"])

# %%
df["src_id"]=le.fit_transform(df["src_id"])

# %%
df["cas_cas_no"]=le.fit_transform(df["cas_cas_no"])

# %%
df["cas_pt"]=le.fit_transform(df["cas_pt"])

# %%
df["cas_source"]=le.fit_transform(df["cas_source"])

# %%
df["cas_match"]=le.fit_transform(df["cas_match"])

# %%
df["umls_pt"]=le.fit_transform(df["umls_pt"])

# %%
df["umls_cui"]=le.fit_transform(df["umls_cui"])

# %%
df["ind_raw_value"]=le.fit_transform(df["ind_raw_value"])

# %%
df["ind_raw_target"]=le.fit_transform(df["ind_raw_target"])

# %%
df["ind_raw_match"]=le.fit_transform(df["ind_raw_match"])

# %%
df["ind_umls_entry_term_match"]=le.fit_transform(df["ind_umls_entry_term_match"])

# %%
df.head()
# Out:
#    src_nm  src_id drug_raw_name  cas_cas_no  cas_pt  cas_source  cas_match  \
# 0       4     291     Fish Oils        1442    1353           2          0
# 1       4     291     Fish Oils        1442    1353           2          0
# 2       4     291     Fish Oils        1442    1353           2          0
# 3       4     291     Fish Oils        1442    1353           2          0
# 4       4     291     Fish Oils        1442    1353           2          0
#
#    umls_pt  umls_cui  ind_raw_value  ind_raw_target  ind_raw_match  \
# 0     1568        96            126             152              0
# 1     1568        96            128             154              0
# 2     1568        96            250             304              0
# 3     1568        96            329             376              0
# 4     1568        96            331             378              0
#
#    ind_umls_entry_term_match
# 0                         13
# 1                         13
# ...

# %%
df.to_csv('final_soltion_drugdata.csv')

# %% [markdown]
# # First, you separate the columns into dependent and independent variables (or features and labels). Then you split those variables into a training and test set.

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X=df[['src_nm', 'src_id', 'cas_cas_no', 'cas_pt','cas_source','cas_match','umls_pt','umls_cui','ind_raw_value','ind_raw_target','ind_raw_match','ind_umls_entry_term_match']]  # Features
y=df['drug_raw_name']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # 80% training and 30% test

# %%
X_train
# Out:
#       src_nm  src_id  cas_cas_no  cas_pt  cas_source  cas_match  umls_pt  \
# 4909       0      97         125    1002           2         17     1201
# 1226       3    1044         175     834           2          0      200
# 1504       3    1122         349    1621           2          4       17
# 272        3     522         931    1619           2         13     1863
# 2379       3     463         896     341           2         13      457
# ...      ...     ...         ...     ...         ...        ...      ...
# 5857       5      97         244    1287           2         13     1505
# 2133       3     471         620     202           2         13      269
# 2460       3     610         883     398           2         13      535
# 4256       0      97        1146     840           2         13     1034
# 1417       3     872        1328     751           2          0      574
#
#       umls_cui  ind_raw_value  ind_raw_target  ind_raw_match  \
# ...

# %%
X_test
# Out:
#       src_nm  src_id  cas_cas_no  cas_pt  cas_source  cas_match  umls_pt  \
# 3384       3     944         193     572           2         13      743
# 4817       1     169         805     973           2         13     1172
# 231        3     571        1102     220           2         13      294
# 1310       3    1065         159     194           2         13      257
# 1730       3     854        1588    1405           2         13     1650
# ...      ...     ...         ...     ...         ...        ...      ...
# 1564       3     756        1467    1435           2         13     1653
# 2759       3     591        1207    1451           2         13     1672
# 5642       3    1351        1459    1232           2         12     1448
# 4710       6      87        1021     951           2         13     1148
# 948        3    1151         207    1463           2         13     1687
#
#       umls_cui  ind_raw_value  ind_raw_target  ind_raw_match  \
# ...

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=200)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7933333333333333

# %%
clf.predict([[6, 84, 376, 606,2,13,779,1461,98,944,0,20]])
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['besipirdine hydrochloride'], dtype=object)

# %% [markdown]
# # implementing extra tree regresseor

# %%
# lets implement label encoding on target column
df["drug_raw_name"]=le.fit_transform(df["drug_raw_name"])
df
# Out:
#       src_nm  src_id  drug_raw_name  cas_cas_no  cas_pt  cas_source  \
# 0          4     291            788        1442    1353           2
# 1          4     291            788        1442    1353           2
# 2          4     291            788        1442    1353           2
# 3          4     291            788        1442    1353           2
# 4          4     291            788        1442    1353           2
# ...      ...     ...            ...         ...     ...         ...
# 5995       6      97           1789         143    1323           2
# 5996       6     104           1790         226    1324           2
# 5997       6      96           1791        1234    1325           2
# 5998       3     642            133        1224     102           2
# 5999       3     642            133        1224     102           2
#
#       cas_match  umls_pt  umls_cui  ind_raw_value  ind_raw_target  \
# 0             0     1568        96            126             152
# ...

# %% [markdown]
# # ExtraTrees Classifier is an ensemble method which is much faster than RandomForest yet equall accurate
#
# before looking at what an extra tree classifier is lets first look at random forest works letts consider a simple data set n features and n raws in a random forest we run multiple trees that each tree comprise of the squre roo of the total number of features that are persent so in our case we have n features so each tree would have square root of n features to train on additionally we will be making use of bootstarp samples or samples with replacemnets that is where we have the out of the bag error score that we can use later on for validation
#
#
# ### How is an extra 3 classified different
#
# the very first difference of an extra tree classifier lies in how we select samples in extra tree classifer,we will be selecting samples for every decision tree without replacemnt so all the samples would be unique in nature.
# the total number of fetaures selected still remain the same that is square root of the total number of features if you are using a classsification task
#
#
#
# ### so what exactly differnce between  random forest and extra tree classifier
#
# lies in the fact that instead of computing the locally optimal split for a feature combination a random value is selectd for the split for the extra tree  so again the whole idea is rather that not spending time and finding out the best splitting point.
#
# i randomly pick up a point and split based on that this leads to more diversified trees and less splitters to avalute when training and extremely random forest.
#
# when extra tree classifiers where tested with the raedily available data sets, we oberved that when we had mnoisy features in our data set extra tree classifires seemed to outperform random forest however wehn all the features are relevent and when you train both extra tree classifers as well as a random forest both methods seem to have achived the same performance be it in terms of accuracy, AUC,ROC values or the f1 score that we are closing

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X=df[['src_nm', 'src_id', 'cas_cas_no', 'cas_pt','cas_source','cas_match','umls_pt','umls_cui','ind_raw_value','ind_raw_target','ind_raw_match','ind_umls_entry_term_match']]  # Features
y=df['drug_raw_name']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # 80% training and 30% test

# %%
#Preparing Extra Tree Regression
from sklearn.ensemble import  ExtraTreesRegressor
ET_Model=ExtraTreesRegressor(n_estimators = 120)


ET_Model.fit(X_train,y_train)
y_predict=ET_Model.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.9891428397824483

# %%
ET_Model.predict([[6, 84, 376, 606,2,13,779,1461,98,944,0,20]])
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but ExtraTreesRegressor was fitted with feature names
#   warnings.warn(
# array([1091.34166667])

# %% [raw]
# preceion
# f1 score
#
# try xg boost on this dataset
# ann will try to use

# %%
le.classes_
# Out:
# array(['(1R-(exo,exo))-3-(4-fluorophenyl)-8-methyl-8- azabicyclo(3.2.1)octane-2-carboxylic acid, methyl ester',
#        "(2',5'-bis-O-(tert-butyldimethylsilyl)-beta-ribofuranosyl)-3'-spiro-5''-(4''-amino-1'',2''-oxathiole-2'',2''-dioxide)thymine",
#        "(2-(2',6'-dimethoxy)phenoxyethylamino)methylbenzo-1,4-dioxane",
#        ..., 'tyrosyl-isoleucyl-glycyl-seryl-arginine',
#        'valyl-leucyl-lysine 4-nitroanilide', 'zeta Carotene'],
#       dtype=object)

# %%
# we can inverse transform 
le.inverse_transform([1091])
# Out:
# array(['ammonium sulfate'], dtype=object)
